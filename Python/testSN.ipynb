# %%
import matplotlib.pyplot as plt
class mrs_network():
    def __init__(self, batch_size=256):
        self.batch_size = batch_size
        self.best_loss = 9999
        self.losses = {'train': [], 'test': []}
        
plt.plot(mrs_network().losses['train'], label='Training loss')
plt.legend()
plt.show()

# %%
# what is mrs_net.losses['train']?
# mrs_net.losses['train'] is a list of the losses of each epoch

# why mrs_net is giving me a error is not defined?
# because you have to run the cell where you define the class mrs_net
# how to define the class mrs_net?
# write class mrs_net in a cell and run it
